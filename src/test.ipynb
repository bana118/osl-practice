# %% [markdown]
# # Jupyter diff Test

# %%
print("jupyter diff test")
# Out:
# Hello

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()
